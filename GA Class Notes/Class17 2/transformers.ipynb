# %% [markdown]
# ### Introduction to Transformers and Huggingface
#
# ![](https://huggingface.co/front/assets/huggingface_logo-noborder.svg)

# %%
#pip install transformers

# %%
import transformers

# %% [markdown]
# ### The `pipeline` object

# %%
#pipeline for sentiment analysis
from transformers import pipeline

# %%
clf = pipeline("sentiment-analysis")
# Out:
# No model was supplied, defaulted to distilbert-base-uncased-finetuned-sst-2-english (https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english)
# Downloading:   0%|          | 0.00/629 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/255M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/226k [00:00<?, ?B/s]

# %%
clf("I've been so excited about the new Justin Bieber record.")
# Out:
# [{'label': 'POSITIVE', 'score': 0.9995564818382263}]

# %%
clf(["Justin Bieber has an amazing sound", "The new Corpse record is terrible."])
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# [{'label': 'POSITIVE', 'score': 0.9998735189437866},
#  {'label': 'NEGATIVE', 'score': 0.9996525049209595}]

# %% [markdown]
# ### Other pipelines
#
# There are many additional pipelines available from Huggingface [here](https://huggingface.co/transformers/main_classes/pipelines.html)

# %%
gen = pipeline("text-generation")
# Out:
# No model was supplied, defaulted to gpt2 (https://huggingface.co/gpt2)
# Downloading:   0%|          | 0.00/665 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/523M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/0.99M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.29M [00:00<?, ?B/s]

# %%
gen("""Tired of beefin' you bums, you can't even pay me enough""")
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': 'Tired of beefin\' you bums, you can\'t even pay me enough?!" said the young guy.\n\n"N-no, I\'m fine. I\'m just waiting and waiting for you, because your mom won\'t let me'}]

# %%
gen = pipeline("text-generation", model = "distilgpt2")
# Out:
# Downloading:   0%|          | 0.00/762 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/336M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/0.99M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.29M [00:00<?, ?B/s]

# %%
gen("""Tired of beefin' you bums, you can't even pay me enough""",
    max_length = 50,
    num_return_sequences = 3)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': "Tired of beefin' you bums, you can't even pay me enough to eat!"},
#  {'generated_text': "Tired of beefin' you bums, you can't even pay me enough!! The bums! Why? You're not going to see me again. You're not happy? You's not happy? You're not okay? You're"},
#  {'generated_text': "Tired of beefin' you bums, you can't even pay me enough!\nThe guys at the Taco Bell also have an old, white belt-pig truck parked right outside the bar. The car was so big the crew can"}]
